# %%
import os

os.listdir("data_melspec/birds")
# Out:
# ['bird1.npy_seg0.npy',
#  'bird1.npy_seg1.npy',
#  'bird1.npy_seg2.npy',
#  'bird1.npy_seg3.npy',
#  'bird1.npy_seg4.npy',
#  'bird1.npy_seg5.npy',
#  'bird1.npy_seg6.npy',
#  'bird1.npy_seg7.npy',
#  'bird1.npy_seg8.npy',
#  'bird10.npy_seg0.npy',
#  'bird10.npy_seg1.npy',
#  'bird10.npy_seg2.npy',
#  'bird10.npy_seg3.npy',
#  'bird10.npy_seg4.npy',
#  'bird10.npy_seg5.npy',
#  'bird10.npy_seg6.npy',
#  'bird10.npy_seg7.npy',
#  'bird10.npy_seg8.npy',
#  'bird2.npy_seg0.npy',
#  'bird2.npy_seg1.npy',
#  'bird2.npy_seg2.npy',
#  'bird2.npy_seg3.npy',
#  'bird2.npy_seg4.npy',
#  'bird2.npy_seg5.npy',
#  'bird2.npy_seg6.npy',
#  'bird2.npy_seg7.npy',
#  'bird2.npy_seg8.npy',
#  'bird3.npy_seg0.npy',
#  'bird3.npy_seg1.npy',
#  'bird3.npy_seg2.npy',
#  'bird3.npy_seg3.npy',
#  'bird3.npy_seg4.npy',
#  'bird3.npy_seg5.npy',
#  'bird3.npy_seg6.npy',
#  'bird3.npy_seg7.npy',
#  'bird3.npy_seg8.npy',
#  'bird4.npy_seg0.npy',
#  'bird4.npy_seg1.npy',
#  'bird4.npy_seg2.npy',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

mel = np.load("data_melspec/birds/bird2.npy_seg2.npy")

plt.figure(figsize=(8,4))
plt.imshow(mel, aspect='auto', origin='lower', cmap='magma')
plt.colorbar()
plt.title("Mel-Spectrogram")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mel = np.load("data_melspec/drone/drone1.npy_seg2.npy")

plt.figure(figsize=(8,4))
plt.imshow(mel, aspect='auto', origin='lower', cmap='magma')
plt.colorbar()
plt.title("Mel-Spectrogram")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mel = np.load("data_melspec/drone/drone2.npy_seg6.npy")

plt.figure(figsize=(8,4))
plt.imshow(mel, aspect='auto', origin='lower', cmap='magma')
plt.colorbar()
plt.title("Mel-Spectrogram")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mel = np.load("data_melspec/wind/wind1.npy_seg3.npy")

plt.figure(figsize=(8,4))
plt.imshow(mel, aspect='auto', origin='lower', cmap='magma')
plt.colorbar()
plt.title("Mel-Spectrogram")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mel = np.load("data_melspec/vehicle/vehicle3.npy_seg5.npy")

plt.figure(figsize=(8,4))
plt.imshow(mel, aspect='auto', origin='lower', cmap='magma')
plt.colorbar()
plt.title("Mel-Spectrogram")
plt.show()

# %%
import sounddevice as sd
print(sd.query_devices())
# Out:
#    0 Microsoft Sound Mapper - Input, MME (2 in, 0 out)
# >  1 Headset (Fuxi-H3), MME (1 in, 0 out)
#    2 Microsoft Sound Mapper - Output, MME (0 in, 2 out)
# <  3 Headphones (Fuxi-H3), MME (0 in, 2 out)
#    4 MSI MP273A (NVIDIA High Definit, MME (0 in, 2 out)
#    5 Primary Sound Capture Driver, Windows DirectSound (2 in, 0 out)
#    6 Headset (Fuxi-H3), Windows DirectSound (1 in, 0 out)
#    7 Primary Sound Driver, Windows DirectSound (0 in, 2 out)
#    8 Headphones (Fuxi-H3), Windows DirectSound (0 in, 2 out)
#    9 MSI MP273A (NVIDIA High Definition Audio), Windows DirectSound (0 in, 2 out)
#   10 Headphones (Fuxi-H3), Windows WASAPI (0 in, 2 out)
#   11 MSI MP273A (NVIDIA High Definition Audio), Windows WASAPI (0 in, 2 out)
#   12 Headset (Fuxi-H3), Windows WASAPI (1 in, 0 out)
#   13 Output (NVIDIA High Definition Audio), Windows WDM-KS (0 in, 2 out)
#   14 Speakers (Realtek HD Audio output), Windows WDM-KS (0 in, 6 out)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

mel = np.load("data_melspec/drone_1/seg_0.npy")

plt.figure(figsize=(8,4))
plt.imshow(mel, aspect='auto', origin='lower', cmap='magma')
plt.colorbar()
plt.title("Mel-Spectrogram")
plt.show()

# %%
import librosa
import matplotlib.pyplot as plt
from extract_time_domain import compute_time_domain_features

filepath = "./data_2205k/drone_1/drone1.wav"
y, sr = librosa.load(filepath, sr=None)

ae, rms, zcr = compute_time_domain_features(y, sr)

plt.figure(figsize=(14,4))
plt.plot(rms, label="RMS")
plt.plot(zcr, label="ZCR")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import librosa
#       2 import matplotlib.pyplot as plt
# ----> 3 from extract_time_domain import compute_time_domain_features
#       5 filepath = "./data_2205k/drone_1/drone1.wav"
#       6 y, sr = librosa.load(filepath, sr=None)
#
# ModuleNotFoundError: No module named 'extract_time_domain'
